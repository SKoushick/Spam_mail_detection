# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

df = pd.read_csv("customer_reviews_unique.csv")

# %%
df.head()
# Out:
#                                review_text  sentiment_score  length  \
# 0     Subscribe now and get rich quick! #0         0.404393      36
# 1  Cheap material, broke within a week. #1         0.534594      39
# 2           Five stars, will buy again! #2         0.647324      30
# 3   Waste of money, avoid at all costs. #3         0.765748      38
# 4         Absolutely love this product! #4         0.409795      32
#
#    verified_purchase  helpful_votes  is_spam
# 0                  1              2        1
# 1                  1              8        0
# 2                  1              3        0
# 3                  0              6        0
# 4                  0              1        0

# %%
X_text = df["review_text"]
X_sentiment = df["sentiment_score"].values.reshape(-1, 1)
X_meta = df[["length", "verified_purchase", "helpful_votes"]]

# %%
vectorizer = TfidfVectorizer()

# %%
X_text_vec = vectorizer.fit_transform(X_text).toarray()
X_all = pd.concat([pd.DataFrame(X_text_vec), pd.DataFrame(X_sentiment), X_meta.reset_index(drop=True)], axis=1)
y = df["is_spam"]

# %%
X_all.columns = X_all.columns.astype(str)

# %%
X_all = pd.concat([pd.DataFrame(X_text_vec), pd.DataFrame(X_sentiment), X_meta.reset_index(drop=True)], axis=1)
X_all.columns = X_all.columns.astype(str)  # Fix mixed column name types

# %%
X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.2, random_state=42)

# %%
model = make_pipeline(StandardScaler(), SVC(kernel='linear'))
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(kernel='linear'))])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(kernel='linear'))])

# %%
preds = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 1.0
