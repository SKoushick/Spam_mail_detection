# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

df = pd.read_csv("youtube_comments_unique.csv")
X_text = df["comment"]
X_behavior = df[["like_count", "reply_count", "account_age_days"]]
vectorizer = TfidfVectorizer()
X_text_vec = vectorizer.fit_transform(X_text).toarray()
X_all = pd.concat([pd.DataFrame(X_text_vec), X_behavior.reset_index(drop=True)], axis=1)
X_all.columns = X_all.columns.astype(str)
y = df["is_spam"]
X_train, X_test, y_train, y_test = train_test_split(X_all, y, test_size=0.2, random_state=0)
model = make_pipeline(StandardScaler(), SVC(kernel='linear'))
model.fit(X_train, y_train)
preds = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 1.0
